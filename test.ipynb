# %%
# !pip install langgraph
# Out:
# Running cells with 'Python 3.10.4' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Python310/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
from IPython.display import Image, display
from core.graph import ChatGraph
graph = ChatGraph()
try:
    display(Image(graph.compiled.get_graph(xray=True).draw_mermaid_png()))
except Exception:
    # This requires some extra dependencies and is optional
    pass

# %%
display(Image(graph.compiled.get_graph(xray=True).draw_mermaid_png()))

# %%
graph.execute("could you please create notes on langgraph based on your knowledge and export it in markdown format ?")
# Out:
# Executing graph with user input: could you please create notes on langgraph based on your knowledge and export it in markdown format ?
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 graph.execute("could you please create notes on langgraph based on your knowledge and export it in markdown format ?")
#
# File c:\Users\deepa\ekline\youtube\core\graph.py:63, in ChatGraph.execute(self, user_input)
#      61 def execute(self, user_input: str) -> ChatState:
#      62     print(f"Executing graph with user input: {user_input}")
# ---> 63     result = self.compiled.invoke(ChatState(user_input=user_input, messages={}))
#      64     state = ChatState(**result)
#      65     print(f"Graph execution result: {state}")
#
# File c:\Users\deepa\ekline\youtube\.venv\lib\site-packages\pydantic\main.py:214, in BaseModel.__init__(self, **data)
# ...
